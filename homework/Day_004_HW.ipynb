# %%
import os
import numpy as np
import pandas as pd

# %%
dir_data = './data/'

# %%
f_app = os.path.join(dir_data, 'HomeCredit_columns_description.csv')
print('Path of read in data: %s' % (f_app))
app_train = pd.read_csv(f_app)
# Out:
# Path of read in data: ./data/HomeCredit_columns_description.csv

# %%
app_train.head(10)
# Out:
#    Unnamed: 0                         Table                 Row  \
# 0           1  application_{train|test}.csv          SK_ID_CURR
# 1           2  application_{train|test}.csv              TARGET
# 2           5  application_{train|test}.csv  NAME_CONTRACT_TYPE
# 3           6  application_{train|test}.csv         CODE_GENDER
# 4           7  application_{train|test}.csv        FLAG_OWN_CAR
# 5           8  application_{train|test}.csv     FLAG_OWN_REALTY
# 6           9  application_{train|test}.csv        CNT_CHILDREN
# 7          10  application_{train|test}.csv    AMT_INCOME_TOTAL
# 8          11  application_{train|test}.csv          AMT_CREDIT
# 9          12  application_{train|test}.csv         AMT_ANNUITY
#
#                                          Description Special Unnamed: 5  \
# 0                           ID of loan in our sample     NaN        NaN
# 1  Target variable (1 - client with payment diffi...     NaN        NaN
# ...

# %%
app_train.tail(5)
# Out:
#      Unnamed: 0                      Table                    Row  \
# 200         217  installments_payments.csv  NUM_INSTALMENT_NUMBER
# 201         218  installments_payments.csv        DAYS_INSTALMENT
# 202         219  installments_payments.csv     DAYS_ENTRY_PAYMENT
# 203         220  installments_payments.csv         AMT_INSTALMENT
# 204         221  installments_payments.csv            AMT_PAYMENT
#
#                                            Description  \
# 200            On which installment we observe payment
# 201  When the installment of previous credit was su...
# 202  When was the installments of previous credit p...
# 203  What was the prescribed installment amount of ...
# 204  What the client actually paid on previous cred...
#
#                                    Special Unnamed: 5 Unnamed: 6
# 200                                    NaN        NaN        NaN
# 201  time only relative to the application        NaN        NaN
# ...

# %%
app_train[5:]
# Out:
#      Unnamed: 0                         Table                          Row  \
# 5             8  application_{train|test}.csv              FLAG_OWN_REALTY
# 6             9  application_{train|test}.csv                 CNT_CHILDREN
# 7            10  application_{train|test}.csv             AMT_INCOME_TOTAL
# 8            11  application_{train|test}.csv                   AMT_CREDIT
# 9            12  application_{train|test}.csv                  AMT_ANNUITY
# 10           13  application_{train|test}.csv              AMT_GOODS_PRICE
# 11           14  application_{train|test}.csv              NAME_TYPE_SUITE
# 12           15  application_{train|test}.csv             NAME_INCOME_TYPE
# 13           16  application_{train|test}.csv          NAME_EDUCATION_TYPE
# 14           17  application_{train|test}.csv           NAME_FAMILY_STATUS
# 15           18  application_{train|test}.csv            NAME_HOUSING_TYPE
# ...

# %%
app_train.Row
# Out:
# 0                       SK_ID_CURR
# 1                           TARGET
# 2               NAME_CONTRACT_TYPE
# 3                      CODE_GENDER
# 4                     FLAG_OWN_CAR
# 5                  FLAG_OWN_REALTY
# 6                     CNT_CHILDREN
# 7                 AMT_INCOME_TOTAL
# 8                       AMT_CREDIT
# 9                      AMT_ANNUITY
# 10                 AMT_GOODS_PRICE
# 11                 NAME_TYPE_SUITE
# 12                NAME_INCOME_TYPE
# 13             NAME_EDUCATION_TYPE
# 14              NAME_FAMILY_STATUS
# 15               NAME_HOUSING_TYPE
# 16      REGION_POPULATION_RELATIVE
# 17                      DAYS_BIRTH
# 18                   DAYS_EMPLOYED
# 19               DAYS_REGISTRATION
# 20                 DAYS_ID_PUBLISH
# 21                     OWN_CAR_AGE
# 22                      FLAG_MOBIL
# 23                  FLAG_EMP_PHONE
# 24                 FLAG_WORK_PHONE
# 25                FLAG_CONT_MOBILE
# 26                      FLAG_PHONE
# ...

# %%
bond=pd.read_csv(f_app, index_col="Unnamed: 0")

# %%
bond.head(10)
# Out:
#                            Table                 Row  \
# 1   application_{train|test}.csv          SK_ID_CURR
# 2   application_{train|test}.csv              TARGET
# 5   application_{train|test}.csv  NAME_CONTRACT_TYPE
# 6   application_{train|test}.csv         CODE_GENDER
# 7   application_{train|test}.csv        FLAG_OWN_CAR
# 8   application_{train|test}.csv     FLAG_OWN_REALTY
# 9   application_{train|test}.csv        CNT_CHILDREN
# 10  application_{train|test}.csv    AMT_INCOME_TOTAL
# 11  application_{train|test}.csv          AMT_CREDIT
# 12  application_{train|test}.csv         AMT_ANNUITY
#
#                                           Description Special Unnamed: 5  \
# 1                            ID of loan in our sample     NaN        NaN
# 2   Target variable (1 - client with payment diffi...     NaN        NaN
# 5         Identification if loan is cash or revolving     NaN        NaN
# 6                                Gender of the client     NaN        NaN
# ...

# %%
bond.index
# Out:
# Int64Index([  1,   2,   5,   6,   7,   8,   9,  10,  11,  12,
#             ...
#             198, 199, 200, 215, 216, 217, 218, 219, 220, 221],
#            dtype='int64', length=205)

# %%
bond.set_index("Table", inplace=True)

# %%
bond.head(10)
# Out:
#                                              Row  \
# Table
# application_{train|test}.csv          SK_ID_CURR
# application_{train|test}.csv              TARGET
# application_{train|test}.csv  NAME_CONTRACT_TYPE
# application_{train|test}.csv         CODE_GENDER
# application_{train|test}.csv        FLAG_OWN_CAR
# application_{train|test}.csv     FLAG_OWN_REALTY
# application_{train|test}.csv        CNT_CHILDREN
# application_{train|test}.csv    AMT_INCOME_TOTAL
# application_{train|test}.csv          AMT_CREDIT
# application_{train|test}.csv         AMT_ANNUITY
#
#                                                                     Description  \
# Table
# application_{train|test}.csv                           ID of loan in our sample
# application_{train|test}.csv  Target variable (1 - client with payment diffi...
# application_{train|test}.csv        Identification if loan is cash or revolving
# application_{train|test}.csv                               Gender of the client
# ...

# %%
bond.index
# Out:
# Index(['application_{train|test}.csv', 'application_{train|test}.csv',
#        'application_{train|test}.csv', 'application_{train|test}.csv',
#        'application_{train|test}.csv', 'application_{train|test}.csv',
#        'application_{train|test}.csv', 'application_{train|test}.csv',
#        'application_{train|test}.csv', 'application_{train|test}.csv',
#        ...
#        'previous_application.csv', 'previous_application.csv',
#        'previous_application.csv', 'installments_payments.csv',
#        'installments_payments.csv', 'installments_payments.csv',
#        'installments_payments.csv', 'installments_payments.csv',
#        'installments_payments.csv', 'installments_payments.csv'],
#       dtype='object', name='Table', length=205)

# %%
bond
# Out:
#                                                       Row  \
# Table
# application_{train|test}.csv                   SK_ID_CURR
# application_{train|test}.csv                       TARGET
# application_{train|test}.csv           NAME_CONTRACT_TYPE
# application_{train|test}.csv                  CODE_GENDER
# application_{train|test}.csv                 FLAG_OWN_CAR
# application_{train|test}.csv              FLAG_OWN_REALTY
# application_{train|test}.csv                 CNT_CHILDREN
# application_{train|test}.csv             AMT_INCOME_TOTAL
# application_{train|test}.csv                   AMT_CREDIT
# application_{train|test}.csv                  AMT_ANNUITY
# application_{train|test}.csv              AMT_GOODS_PRICE
# application_{train|test}.csv              NAME_TYPE_SUITE
# application_{train|test}.csv             NAME_INCOME_TYPE
# application_{train|test}.csv          NAME_EDUCATION_TYPE
# application_{train|test}.csv           NAME_FAMILY_STATUS
# ...

# %%
app_train.set_index("Unnamed: 0", inplace=True)

# %%
app_train.head(10)
# Out:
#                                    Table                 Row  \
# Unnamed: 0
# 1           application_{train|test}.csv          SK_ID_CURR
# 2           application_{train|test}.csv              TARGET
# 5           application_{train|test}.csv  NAME_CONTRACT_TYPE
# 6           application_{train|test}.csv         CODE_GENDER
# 7           application_{train|test}.csv        FLAG_OWN_CAR
# 8           application_{train|test}.csv     FLAG_OWN_REALTY
# 9           application_{train|test}.csv        CNT_CHILDREN
# 10          application_{train|test}.csv    AMT_INCOME_TOTAL
# 11          application_{train|test}.csv          AMT_CREDIT
# 12          application_{train|test}.csv         AMT_ANNUITY
#
#                                                   Description Special  \
# Unnamed: 0
# 1                                    ID of loan in our sample     NaN
# 2           Target variable (1 - client with payment diffi...     NaN
# ...

# %%
app_train.reset_index(inplace=True)

# %%
app_train.head(10)
# Out:
#    Unnamed: 0                         Table                 Row  \
# 0           1  application_{train|test}.csv          SK_ID_CURR
# 1           2  application_{train|test}.csv              TARGET
# 2           5  application_{train|test}.csv  NAME_CONTRACT_TYPE
# 3           6  application_{train|test}.csv         CODE_GENDER
# 4           7  application_{train|test}.csv        FLAG_OWN_CAR
# 5           8  application_{train|test}.csv     FLAG_OWN_REALTY
# 6           9  application_{train|test}.csv        CNT_CHILDREN
# 7          10  application_{train|test}.csv    AMT_INCOME_TOTAL
# 8          11  application_{train|test}.csv          AMT_CREDIT
# 9          12  application_{train|test}.csv         AMT_ANNUITY
#
#                                          Description Special Unnamed: 5  \
# 0                           ID of loan in our sample     NaN        NaN
# 1  Target variable (1 - client with payment diffi...     NaN        NaN
# ...

# %%
app_train.set_index("Unnamed: 0", inplace=True)

# %%
app_train.loc[10]
# Out:
# Table          application_{train|test}.csv
# Row                        AMT_INCOME_TOTAL
# Description            Income of the client
# Special                                 NaN
# Unnamed: 5                              NaN
# Unnamed: 6                              NaN
# Name: 10, dtype: object

# %%
app_train.loc[[1, 2]]
# Out:
#                                    Table         Row  \
# Unnamed: 0
# 1           application_{train|test}.csv  SK_ID_CURR
# 2           application_{train|test}.csv      TARGET
#
#                                                   Description Special  \
# Unnamed: 0
# 1                                    ID of loan in our sample     NaN
# 2           Target variable (1 - client with payment diffi...     NaN
#
#            Unnamed: 5 Unnamed: 6
# Unnamed: 0
# 1                 NaN        NaN
# 2                 NaN        NaN

# %%
app_train_1=pd.read_csv(f_app)

# %%
app_train_1.iloc[15]
# Out:
# Unnamed: 0                                                    18
# Table                               application_{train|test}.csv
# Row                                            NAME_HOUSING_TYPE
# Description    What is the housing situation of the client (r...
# Special                                                      NaN
# Unnamed: 5                                                   NaN
# Unnamed: 6                                                   NaN
# Name: 15, dtype: object

# %%
app_train_1.iloc[1:5]
# Out:
#    Unnamed: 0                         Table                 Row  \
# 1           2  application_{train|test}.csv              TARGET
# 2           5  application_{train|test}.csv  NAME_CONTRACT_TYPE
# 3           6  application_{train|test}.csv         CODE_GENDER
# 4           7  application_{train|test}.csv        FLAG_OWN_CAR
#
#                                          Description Special Unnamed: 5  \
# 1  Target variable (1 - client with payment diffi...     NaN        NaN
# 2        Identification if loan is cash or revolving     NaN        NaN
# 3                               Gender of the client     NaN        NaN
# 4                      Flag if the client owns a car     NaN        NaN
#
#   Unnamed: 6
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
app_train_1.loc[1:5]
# Out:
#    Unnamed: 0                         Table                 Row  \
# 1           2  application_{train|test}.csv              TARGET
# 2           5  application_{train|test}.csv  NAME_CONTRACT_TYPE
# 3           6  application_{train|test}.csv         CODE_GENDER
# 4           7  application_{train|test}.csv        FLAG_OWN_CAR
# 5           8  application_{train|test}.csv     FLAG_OWN_REALTY
#
#                                          Description Special Unnamed: 5  \
# 1  Target variable (1 - client with payment diffi...     NaN        NaN
# 2        Identification if loan is cash or revolving     NaN        NaN
# 3                               Gender of the client     NaN        NaN
# 4                      Flag if the client owns a car     NaN        NaN
# 5                Flag if client owns a house or flat     NaN        NaN
#
#   Unnamed: 6
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN

# %%
app_train_1.loc[3, "Table"]
# Out:
# 'application_{train|test}.csv'

# %%
app_train_1.rename(columns={"Unnamed: 0":"Index"}, inplace=True)

# %%
app_train_1.head(10)
# Out:
#    Index                         Table                 Row  \
# 0      1  application_{train|test}.csv          SK_ID_CURR
# 1      2  application_{train|test}.csv              TARGET
# 2      5  application_{train|test}.csv  NAME_CONTRACT_TYPE
# 3      6  application_{train|test}.csv         CODE_GENDER
# 4      7  application_{train|test}.csv        FLAG_OWN_CAR
# 5      8  application_{train|test}.csv     FLAG_OWN_REALTY
# 6      9  application_{train|test}.csv        CNT_CHILDREN
# 7     10  application_{train|test}.csv    AMT_INCOME_TOTAL
# 8     11  application_{train|test}.csv          AMT_CREDIT
# 9     12  application_{train|test}.csv         AMT_ANNUITY
#
#                                          Description Special Unnamed: 5  \
# 0                           ID of loan in our sample     NaN        NaN
# 1  Target variable (1 - client with payment diffi...     NaN        NaN
# 2        Identification if loan is cash or revolving     NaN        NaN
# ...

# %%
app_train_1.rename(index={2:3}, inplace=True)

# %%
app_train_1[:5]
# Out:
#    Index                         Table                 Row  \
# 0      1  application_{train|test}.csv          SK_ID_CURR
# 1      2  application_{train|test}.csv              TARGET
# 3      5  application_{train|test}.csv  NAME_CONTRACT_TYPE
# 3      6  application_{train|test}.csv         CODE_GENDER
# 4      7  application_{train|test}.csv        FLAG_OWN_CAR
#
#                                          Description Special Unnamed: 5  \
# 0                           ID of loan in our sample     NaN        NaN
# 1  Target variable (1 - client with payment diffi...     NaN        NaN
# 3        Identification if loan is cash or revolving     NaN        NaN
# 3                               Gender of the client     NaN        NaN
# 4                      Flag if the client owns a car     NaN        NaN
#
#   Unnamed: 6
# 0        NaN
# 1        NaN
# 3        NaN
# 3        NaN
# 4        NaN

# %%
app_train_1.drop(labels=["Table"], axis="columns")
# Out:
#      Index                          Row  \
# 0        1                   SK_ID_CURR
# 1        2                       TARGET
# 3        5           NAME_CONTRACT_TYPE
# 3        6                  CODE_GENDER
# 4        7                 FLAG_OWN_CAR
# 5        8              FLAG_OWN_REALTY
# 6        9                 CNT_CHILDREN
# 7       10             AMT_INCOME_TOTAL
# 8       11                   AMT_CREDIT
# 9       12                  AMT_ANNUITY
# 10      13              AMT_GOODS_PRICE
# 11      14              NAME_TYPE_SUITE
# 12      15             NAME_INCOME_TYPE
# 13      16          NAME_EDUCATION_TYPE
# 14      17           NAME_FAMILY_STATUS
# 15      18            NAME_HOUSING_TYPE
# 16      19   REGION_POPULATION_RELATIVE
# 17      20                   DAYS_BIRTH
# 18      21                DAYS_EMPLOYED
# 19      22            DAYS_REGISTRATION
# 20      23              DAYS_ID_PUBLISH
# 21      24                  OWN_CAR_AGE
# ...
