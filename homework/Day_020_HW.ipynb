# %%
import os 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
matrix = np.random.uniform(low = -1.0, high = 1.0, size = (10, 10))

# %%
matrix
# Out:
# array([[-0.73618167, -0.98545913,  0.76279769, -0.38409195,  0.02135012,
#         -0.66820689,  0.5122299 ,  0.03600614,  0.14077463, -0.97878802],
#        [ 0.73028262, -0.42278202,  0.39490314,  0.75955216, -0.1264526 ,
#          0.89365175, -0.51257048, -0.51034618, -0.17631415, -0.45115985],
#        [ 0.70502868, -0.14590527, -0.7582676 ,  0.95157032,  0.99411613,
#          0.41175393, -0.28888484,  0.73607375, -0.42041927,  0.50721225],
#        [-0.22724509, -0.38883716,  0.05729245,  0.79708638,  0.07991802,
#         -0.04031148,  0.83857794, -0.38805828,  0.42768553, -0.50959399],
#        [-0.85827216,  0.01016273,  0.21908537, -0.72301252, -0.79072917,
#          0.48092912,  0.91875856, -0.88319191, -0.47719728, -0.31949634],
#        [ 0.35319715,  0.72789013, -0.05856452, -0.35562946, -0.79383048,
#         -0.55931498, -0.32152347,  0.52846485,  0.15969806,  0.94952626],
#        [ 0.04378957, -0.18532354,  0.15003812,  0.81936645, -0.51965603,
#          0.28297226, -0.75528543, -0.09386619, -0.57030461, -0.33594605],
#        [-0.22769793, -0.82543505, -0.8474759 , -0.08407244, -0.70649281,
#          0.55941193,  0.06210369,  0.55990397, -0.08023503, -0.71607586],
#        [-0.87959466,  0.74927631, -0.39996463,  0.86256018,  0.46876323,
#          0.17009317,  0.15073794, -0.50105959, -0.80377989,  0.27466265],
#        [-0.81771453, -0.98189672, -0.02919186,  0.95075162, -0.62149502,
#         -0.60720758, -0.93896512,  0.19172183, -0.65483568,  0.75207903]])

# %%
plt.figure(figsize = (10,10))
sns.heatmap(matrix, cmap = plt.cm.RdYlBu_r, vmin = -0.25, annot = True, vmax = 0.6)
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1, 'Correlation Heatmap')

# %%
nrow = 1000
ncol = 3
matrix = np.random.uniform(low = -1.0, high = 1.0, size = (nrow, ncol))

# %%
indice = np.random.choice([0,1,2], size = nrow)
plot_data = pd.DataFrame(matrix, indice).reset_index()

# %%
plot_data
# Out:
#      index         0         1         2
# 0        2 -0.503404  0.989343 -0.775475
# 1        2 -0.192710  0.271034  0.139736
# 2        2  0.019082  0.152347 -0.509664
# 3        0 -0.076178 -0.959805  0.330390
# 4        1 -0.746812  0.297560  0.700655
# 5        1  0.311416  0.711946  0.751322
# 6        0  0.308508 -0.017948 -0.104595
# 7        1  0.484153  0.349541  0.272141
# 8        1 -0.509218 -0.689214 -0.991290
# 9        0  0.815948  0.340245  0.268920
# 10       1 -0.600480  0.392197 -0.177345
# 11       1 -0.346902 -0.958911 -0.665629
# 12       0  0.668859  0.804075 -0.428820
# 13       0  0.581723  0.687069 -0.928366
# 14       2 -0.146868  0.204693  0.141519
# 15       2 -0.832828  0.378489 -0.625255
# 16       2  0.217156 -0.053136 -0.885325
# 17       2 -0.886094 -0.768057 -0.388153
# 18       1 -0.049620  0.409918 -0.828638
# 19       2  0.249504  0.456235  0.193114
# 20       0 -0.898897  0.264749  0.593721
# 21       1  0.001519  0.444309  0.270192
# 22       2 -0.255649 -0.948161 -0.648871
# 23       2 -0.083857 -0.575955 -0.986477
# 24       1  0.874303 -0.816167 -0.828728
# 25       0 -0.588627  0.446777  0.816571
# 26       1 -0.694077  0.089255  0.182841
# 27       2  0.680484 -0.067696  0.007009
# 28       1  0.465260 -0.018164 -0.094579
# 29       1 -0.482118 -0.728729 -0.091341
# ..     ...       ...       ...       ...
# 970      1 -0.040479 -0.037158 -0.842373
# 971      2  0.353785  0.131786  0.132348
# 972      2  0.953753  0.836031 -0.284112
# 973      0  0.894247  0.665944 -0.357423
# 974      1 -0.882636 -0.878140 -0.986153
# 975      2  0.414866 -0.146821  0.961169
# 976      0  0.565043 -0.003312  0.129452
# 977      2 -0.506295 -0.033040 -0.094166
# 978      0 -0.234870 -0.864102  0.883298
# 979      2  0.521532  0.309061  0.297763
# 980      2  0.634789  0.988045 -0.359956
# 981      2 -0.544137 -0.621864 -0.705923
# 982      0  0.482342 -0.602895  0.996412
# 983      0 -0.748185 -0.346055 -0.935464
# 984      0 -0.495726  0.323978  0.880420
# 985      2 -0.678994 -0.496409 -0.892042
# 986      2 -0.233735 -0.541840 -0.374376
# 987      2 -0.521177 -0.702527 -0.410017
# 988      2  0.265481 -0.314736  0.870293
# 989      2  0.230975 -0.977430 -0.066624
# 990      0  0.986121  0.167610  0.173092
# 991      1 -0.118865 -0.280563  0.596159
# 992      0 -0.693543 -0.012646  0.996526
# 993      2 -0.921226  0.961753 -0.897500
# 994      1  0.826195 -0.341521  0.642117
# 995      0 -0.452403  0.740089  0.191705
# 996      1  0.910064 -0.827651 -0.388018
# 997      1  0.975429  0.196386 -0.089364
# 998      0 -0.463537  0.918984 -0.907887
# 999      1  0.293980  0.870165  0.338125
#
# [1000 rows x 4 columns]

# %%
grid = sns.PairGrid(data = plot_data, size = 3, diag_sharey=False, hue = 'index', vars = [x for x in list(plot_data.columns) if x != 'index'])
grid.map_upper(plt.scatter, alpha = 0.2)
grid.map_diag(sns.kdeplot)
grid.map_lower(sns.kdeplot, cmap = plt.cm.OrRd_r)

plt.show()

# %%
nrow = 1000
ncol = 3
matrix = np.random.randn(nrow, ncol)

# %%
indice = np.random.choice([0, 1, 2], size = nrow)
plot_data = pd.DataFrame(matrix, indice).reset_index()

# %%
plot_data
# Out:
#      index         0         1         2
# 0        0  0.631367 -0.821579 -0.422963
# 1        2 -0.562914 -0.051314  0.322841
# 2        2 -0.446482  1.020427  0.864810
# 3        2 -0.085284  0.071869 -0.522739
# 4        0  0.982299 -0.704209  0.748357
# 5        0  1.505005  0.690823 -1.417361
# 6        2 -0.210221 -2.311381  2.667648
# 7        1 -0.116398  0.969888 -0.260307
# 8        1  0.013723 -0.708218  0.875486
# 9        2 -0.747813  1.425976  0.107579
# 10       1 -0.711456 -1.014771 -1.233261
# 11       1  0.794409 -1.823728  0.061798
# 12       2 -0.835211  1.674960  0.126643
# 13       0  0.399915 -0.322965  1.949617
# 14       1 -0.086667 -0.276841 -1.126033
# 15       1 -0.419505 -0.602967 -0.357748
# 16       2 -0.230226 -0.459091 -0.428881
# 17       1 -0.340287  0.267012 -0.972770
# 18       1  0.187559 -0.701229 -0.865215
# 19       2  0.330960 -0.558306  1.256108
# 20       2 -0.521754  0.604616 -0.516650
# 21       2  1.224336  0.665897  1.034612
# 22       0  0.317676 -1.480573 -0.496495
# 23       1 -0.318442  0.658748 -0.182495
# 24       1 -0.314796  0.669206 -0.994201
# 25       1 -0.019550  1.617533  0.272354
# 26       0  0.194636  2.609565  0.484616
# 27       0  0.791205 -0.726132  0.542905
# 28       0 -0.291386  0.317338 -0.483079
# 29       0 -0.294319  1.058038 -0.475132
# ..     ...       ...       ...       ...
# 970      1  1.572810 -0.217362  0.654686
# 971      2  0.245348  1.936093  0.522755
# 972      0  1.378166 -0.930027 -1.840309
# 973      2 -0.035784 -1.519532 -0.774499
# 974      2  1.204125 -0.931363  0.214481
# 975      2  0.385869 -0.993208 -0.490615
# 976      2  0.497793  1.649256  0.043852
# 977      0 -0.762133  0.850045  0.054378
# 978      0 -0.613327 -1.380372 -0.549476
# 979      1 -0.846465 -0.145924  1.565141
# 980      0  0.597475  0.727647 -0.562876
# 981      2 -1.819740 -0.652781  0.172180
# 982      1  1.621370 -0.275413  0.762596
# 983      1 -1.470024 -0.502559  0.447404
# 984      1 -0.390150  0.111958  0.613716
# 985      1 -0.098868 -1.713797  0.383080
# 986      0  0.823014 -0.063647  0.939115
# 987      0  0.440109 -0.578465  1.962977
# 988      1 -0.661801  0.051455  0.316879
# 989      1  1.309931 -1.158206  0.399996
# 990      2 -0.617677  0.248525  0.475364
# 991      1  1.291327 -0.498485  0.152678
# 992      1  0.140861  1.509472  0.843161
# 993      1 -0.264528  0.642882  1.303454
# 994      0  0.949474 -0.591479 -1.620496
# 995      1  0.236765 -0.376557 -0.695971
# 996      0  0.837973  1.408941  0.409736
# 997      0  2.027364  1.491991 -1.768400
# 998      0 -3.313192  0.480119  0.693278
# 999      1 -0.215771 -0.339999  1.181398
#
# [1000 rows x 4 columns]

# %%
grid = sns.PairGrid(data = plot_data, size = 3, diag_sharey=False, hue = 'index', vars = [x for x in list(plot_data.columns) if x != 'index'])
grid.map_upper(plt.scatter, alpha = 0.2)
grid.map_diag(sns.kdeplot)
grid.map_lower(sns.kdeplot, cmap = plt.cm.OrRd_r)

plt.show()
